# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import peakutils
from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
#from sklearn.decomposition import PCA
#from scipy.signal import savgol_filter
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
# %matplotlib inline
plt.rcParams['figure.figsize'] = [30, 15]

# %%
data_train = pd.read_excel('/home/ashry/Downloads/CGL_HMEC_220206.xlsx')

# %%
data_train.head()
# Out:
#      ScnrId  Dry Matter  Protein   Fat   Ash  cADF   cNDF  cStarch WaveNumber  \
# 0  21020022       57.95     4.87  1.95  1.21  5.73  12.37    35.61  4373990_6
# 1  21020013       57.95     4.87  1.95  1.21  5.73  12.37    35.61  4373990_6
# 2  21020022       57.95     4.87  1.95  1.21  5.73  12.37    35.61  4373990_5
# 3  21020013       57.95     4.87  1.95  1.21  5.73  12.37    35.61  4373990_5
# 4  21020022       57.95     4.87  1.95  1.21  5.73  12.37    35.61  4373990_4
#
#    3921.568654477596  ...  7284.035449847579  7297.648675739765  \
# 0          13.399379  ...          49.940798          50.491796
# 1          14.972573  ...          49.818196          50.367869
# 2          12.837995  ...          48.970731          49.523932
# 3          14.864465  ...          50.081785          50.703286
# 4          12.541281  ...          48.336051          48.838288
#
#    7311.261901631951  7324.875127524137  7338.488353416324  7352.10157930851  \
# ...

# %%
def convert_abs(input):
    for i in range(input.shape[0]):
        input.iloc[i] = 2-np.log10(input.iloc[i])
    return input

# %%
Dm = data_train['Fat']
spectra_ref = data_train.drop(['ScnrId','Dry Matter','Protein','Fat','Ash','cADF','cNDF','cStarch','WaveNumber'],axis=1)
wav = spectra_ref.keys().astype(str)
spectra_ref.columns =wav

# %%
spectra_abs =  convert_abs(spectra_ref.copy(deep=True))

# %%
pls = PLSRegression(n_components=39)
scores = cross_val_score(pls,spectra_abs,Dm,cv=5,scoring='r2')
np.mean(scores)
# Out:
# 0.5634870746807042
